# %%
# !pip install notebook

# %%
import pandas as pd
import requests
import io
    
# # Downloading the csv file from your GitHub account

# url = "https://gitlab.com/90477_mls_4ds_ii/pr7/-/raw/main/data/new-york-air-quality.csv" # Make sure the url is the raw version of the file on GitHub
# download = requests.get(url).content

# # Reading the downloaded content and turning it into a pandas dataframe

# df = pd.read_csv(io.StringIO(download.decode('utf-8')), sep = ',')

# # Printing out the first 5 rows of the dataframe

# print (df.head())

# %%
dira = 'C:\\Users\\AgaPakos\\Documents\\UE\\ERAZMUS\\Bolonia\\STUDY\\Machine Learning Systems for Data Science - Systems and Algorithms for Data Science\\covid19\\new-york-air-quality.csv'
df = pd.read_csv(dira)

# dirm =
# df = pd.read_csv(dirm)

# dird =
# df = pd.read_csv(dird)

pd.DataFrame.head(df, 5)
# Out:
#          date  pm25  o3  no2  co
# 0  01/11/2022    40  28   20   3
# 1  02/11/2022    45  23   25   3
# 2  03/11/2022    53  17   26   4
# 3  04/11/2022    47  24   10   1
# 4  05/11/2022    31  21    6   1
